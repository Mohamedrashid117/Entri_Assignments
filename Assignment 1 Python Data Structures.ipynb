# %% [markdown]
# ## Topic :List

# %% [markdown]
# 1. Create a list of 5 random numbers and print the list.
# 2. Insert 3 new values to the list and print the updated list.
# 3. Try to use a for loop to print each element in the list.

# %%
rand=(3,5,10,20,25)
print(rand)
# Out:
# (3, 5, 10, 20, 25)

# %%
rand=list(rand)
rand.extend([30,40,45])
print(rand)
# Out:
# [3, 5, 10, 20, 25, 30, 40, 45, 30, 40, 45]

# %%
for i in rand:
    print(i)
# Out:
# 3
# 5
# 10
# 20
# 25
# 30
# 40
# 45

# %% [markdown]
# ###Topic:Tuple

# %%
# Create and print a tuple of 5 values
tup = (3, 5, 10, 20, 25)
print(tup)

# Iterate over the tuple values
for value in tup:
    print(value)
